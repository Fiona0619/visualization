# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# Next, make some sample data so that we have something to plot!
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
# Then make our basic scatterplot (we’ll break it down after!)

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %% [markdown]
# Let’s try modifying our graph
#
#     We want to keep our figure and axis definition the same
#     So we only edit our axis object

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %% [markdown]
# We can also make a line plot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %% [markdown]
# Can you modify our existing code to produce a histogram?

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 fig, ax = plt.subplots(figsize=(5, 3))
# ----> 2 ax.hist(x,y)
#
# File c:\Users\fansh\anaconda4\envs\dsi_participant\lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\fansh\anaconda4\envs\dsi_participant\lib\site-packages\matplotlib\axes\_axes.py:7001, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6997 # Loop through datasets
#    6998 for i in range(nx):
#    6999     # this will automatically overwrite bins,
#    7000     # so that each histogram uses the same bins
# -> 7001     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7002     tops.append(m)
#    7003 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File c:\Users\fansh\anaconda4\envs\dsi_participant\lib\site-packages\numpy\lib\histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File c:\Users\fansh\anaconda4\envs\dsi_participant\lib\site-packages\numpy\lib\histograms.py:431, in _get_bin_edges(a, bins, range, weights)
#     429     bin_edges = np.asarray(bins)
#     430     if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431         raise ValueError(
#     432             '`bins` must increase monotonically, when an array')
#     434 else:
#     435     raise ValueError('`bins` must be 1d, when an array')
#
# ValueError: `bins` must increase monotonically, when an array

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Plot Labels
# Adding axis labels and titles
# Let’s add to the last plot we made

# %%
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %% [markdown]
# Modifying labels and titles
# We can modify our labels and titles’ appearance by using font dictionaries (‘fontdict’)
# First, make a dictionary with the properties we want for our labels

# %%
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

# %% [markdown]
# Modifying labels and titles
# Then we’ll add fontdict arguments to our previous lineplot

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %% [markdown]
# Moving labels and titles
# We can move our lables with the loc argument

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %% [markdown]
# Customizing plot appearance
# Modifying data points
# Remake our basic scatterplot, but this time add color and marker arguments ( NOTE: American spelling)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter( x,
          y,
          marker='*',         # NEW ADDITIONS
          color = "indigo")   # NEW ADDITIONS

fig.show()
# Out:
# C:\Users\fansh\AppData\Local\Temp\ipykernel_13988\3430078393.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Modifying data points
# We can also adjust the style and width of the line connecting our points

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(x,
        y,
        marker='*', 
        color = 'indigo', 
        linestyle = '--',   # NEW ADDITIONS
        linewidth = 2)      # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\fansh\AppData\Local\Temp\ipykernel_13988\2751619806.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Modifying data points: Colour
# We can modify colour using named colors
# https://matplotlib.org/stable/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py
# Or we can use hex codes

# %%
fig, ax = plt.subplots(figsize=(5, 3))
# color being the new addition
ax.plot(x,y,marker='*', color = "#7425b9", linestyle = '--',linewidth = 2)
fig.show()
# Out:
# C:\Users\fansh\AppData\Local\Temp\ipykernel_13988\183414492.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Modifying data points
# Let’s customize our plot further

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y,marker='*',
        markersize = 12,              # NEW ADDITIONS
        color = '#7425b9',
        linestyle = '--',
        linewidth = 2,
        markeredgecolor = '#fa9359',  # NEW ADDITIONS
        markerfacecolor = '#fa9359' ) # NEW ADDITIONS

# %% [markdown]
# Grid lines
# We can add grid lines to our axis object using .grid()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.grid(axis = 'y')

# %% [markdown]
# Activity: Can you modify the appearance (colour, width, linestyle) of our grid lines using what we learned before?
#
# Grid lines
# We can add grid lines to our axis object using .grid()

# %% [markdown]
# Activity: Can you modify the appearance (colour, width, linestyle) of our grid lines using what we learned before?

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.grid(axis = 'y', 
        color = "blue",
        linewidth = 2, 
        linestyle = '-.')
